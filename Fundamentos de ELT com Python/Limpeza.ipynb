# %%
import pandas as pd

# %%
df = pd.read_csv('ocorrencia.csv', parse_dates=['ocorrencia_dia'])
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-05-01
# 1         GUARULHOS            SP                 SBGR     2012-06-01
# 2            VIAMÃO            RS                 ****     2012-06-01
# 3     SÃO SEBASTIÃO            SP                 ****     2012-06-01
# 4          SÃO SEPÉ            RS                 ****     2012-06-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %%
df.loc[df.ocorrencia_uf == 'RS']
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5145              80458               80458                 ACIDENTE
# 5146              80452               80452                 ACIDENTE
# 5147              80457               80457          INCIDENTE GRAVE
# 5148              80460               80460                INCIDENTE
# 5149              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-05-01
# 1            GUARULHOS            SP                 SBGR     2012-06-01
# 2               VIAMÃO            RS                 ****     2012-06-01
# 3        SÃO SEBASTIÃO            SP                 ****     2012-06-01
# 4             SÃO SEPÉ            RS                 ****     2012-06-01
# ...                ...           ...                  ...            ...
# 5145             JATAÍ            GO                 ####     2021-12-30
# 5146           MARACAÍ            SP                *****     2021-12-31
# 5147     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5148          CURITIBA            PR                 SBBI     2021-12-31
# 5149         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5145        20:30:00                    0
# 5146        09:30:00                    0
# 5147        11:59:00                    0
# 5148        15:12:00                    0
# 5149        20:30:00                    0
#
# [5150 rows x 9 columns]

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %%
df.loc[[0,2,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 2               45333               45333                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0       PORTO ALEGRE            RS                 SBPA     2012-05-01
# 2             VIAMÃO            RS                 ****     2012-06-01
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 0         20:27:00                    0
# 2         13:00:00                    0
# 40        13:55:00                    0

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 52242                 2012-05-01        20:27:00                    0
# 45331                 2012-06-01        13:44:00                    3
# 45333                 2012-06-01        13:00:00                    0
# 45401                 2012-06-01        17:00:00                    0
# 45407                 2012-06-01        16:30:00                    0

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5145               80458                 ACIDENTE             JATAÍ
# 5146               80452                 ACIDENTE           MARACAÍ
# 5147               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5148               80460                INCIDENTE          CURITIBA
# 5149               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-05-01        20:27:00
# 1               SP                 SBGR     2012-06-01        13:44:00
# 2               RS                 ****     2012-06-01        13:00:00
# 3               SP                 ****     2012-06-01        17:00:00
# 4               RS                 ****     2012-06-01        16:30:00
# ...            ...                  ...            ...             ...
# 5145            GO                 ####     2021-12-30        20:30:00
# 5146            SP                *****     2021-12-31        09:30:00
# 5147            RS                 SSNH     2021-12-31        11:59:00
# 5148            PR                 SBBI     2021-12-31        15:12:00
# 5149            PE                 SBPL     2021-12-31        20:30:00
#
#       total_recomendacoes
# 0                       0
# 1                       3
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 5145                    0
# 5146                    0
# 5147                    0
# 5148                    0
# 5149                    0
#
# [5150 rows x 8 columns]

# %%
# df.loc[df.ocorrencia_uf == 'RS', ['ocorrencia_classificacao']] = 'INCIDENTE GRAVE'
# df.loc[df.ocorrencia_uf == 'RS']

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-05-01        20:27:00
# 1            SP                 SBGR     2012-06-01        13:44:00
# 2            RS                 <NA>     2012-06-01        13:00:00
# 3            SP                 <NA>     2012-06-01        17:00:00
# 4            RS                 <NA>     2012-06-01        16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %%
df.replace(['**', '****', '*****', 'NULL', '####', '###!', ], pd.NA, inplace=True)
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5145               80458                 ACIDENTE             JATAÍ
# 5146               80452                 ACIDENTE           MARACAÍ
# 5147               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5148               80460                INCIDENTE          CURITIBA
# 5149               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-05-01        20:27:00
# 1               SP                 SBGR     2012-06-01        13:44:00
# 2               RS                 <NA>     2012-06-01        13:00:00
# 3               SP                 <NA>     2012-06-01        17:00:00
# 4               RS                 <NA>     2012-06-01        16:30:00
# ...            ...                  ...            ...             ...
# 5145            GO                 <NA>     2021-12-30        20:30:00
# 5146            SP                 <NA>     2021-12-31        09:30:00
# 5147            RS                 SSNH     2021-12-31        11:59:00
# 5148            PR                 SBBI     2021-12-31        15:12:00
# 5149            PE                 SBPL     2021-12-31        20:30:00
#
#       total_recomendacoes
# 0                       0
# 1                       3
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 5145                    0
# 5146                    0
# 5147                    0
# 5148                    0
# 5149                    0
#
# [5150 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1897
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64
